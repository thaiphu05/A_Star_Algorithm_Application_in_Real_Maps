# %%
import torch
import torch.nn as nn
import torch.optim as optim
import networkx as nx
import numpy as np
import osmnx as ox
import random
from math import radians, cos, sqrt
from sklearn.model_selection import train_test_split

# %%
# Hàm tính khoảng cách Euclidean
def euclidean(lat1, lon1, lat2, lon2):
    lat_mean = radians((lat1 + lat2) / 2)
    dx = (lon2 - lon1) * 111320 * cos(lat_mean)
    dy = (lat2 - lat1) * 111320
    return sqrt(dx**2 + dy**2)

# %%
G = ox.graph_from_xml('map_new.osm')

G_simple = G.to_undirected()

nodes = list(G_simple.nodes)

X = []
y = []

import pandas as pd
import numpy as np

df= pd.read_csv('shortest_path_dataset.csv')
X = df[['node1_x','node1_y','node2_x','node2_y']].values
y = df[['shortest_distance','nodes_between']].values

# Compute Euclidean distances for all rows
euclidean_distances = np.array([euclidean(lat1, lon1, lat2, lon2) for lat1, lon1, lat2, lon2 in X])

# Concatenate as a new feature column
X = np.hstack([X, euclidean_distances.reshape(-1, 1)])

X = np.array(X)
y = np.array(y)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
class HeuristicNet(nn.Module):
    def __init__(self):
        super(HeuristicNet, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(5, 64),
            nn.ReLU(),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Linear(32, 2)
        )

    def forward(self, x):
        return self.net(x)

model = HeuristicNet()
criterion = nn.SmoothL1Loss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.float32)

# %%
for epoch in range(500):
    model.train()
    optimizer.zero_grad()
    
    outputs = model(X_train_tensor)
    loss = criterion(outputs, y_train_tensor)
    
    loss.backward()
    optimizer.step()
    
    if epoch % 10 == 0:
        print(f"Epoch {epoch}, Loss: {loss.item():.4f}")
        
        # Thêm đánh giá trên tập validation
        model.eval()
        with torch.no_grad():
            val_outputs = model(torch.tensor(X_test, dtype=torch.float32))
            val_loss = criterion(val_outputs, torch.tensor(y_test, dtype=torch.float32))
            print(f"Validation Loss: {val_loss.item():.4f}")
# Out:
# Epoch 0, Loss: 644.6840
# Validation Loss: 640.0905
# Epoch 10, Loss: 608.2023
# Validation Loss: 604.7014
# Epoch 20, Loss: 574.2244
# Validation Loss: 570.4298
# Epoch 30, Loss: 534.6895
# Validation Loss: 530.0490
# Epoch 40, Loss: 482.0434
# Validation Loss: 475.7006
# Epoch 50, Loss: 409.7651
# Validation Loss: 401.0832
# Epoch 60, Loss: 311.6351
# Validation Loss: 300.1382
# Epoch 70, Loss: 212.2134
# Validation Loss: 207.0844
# Epoch 80, Loss: 198.3612
# Validation Loss: 198.5630
# Epoch 90, Loss: 199.5437
# Validation Loss: 198.8273
# Epoch 100, Loss: 193.7736
# Validation Loss: 192.8310
# Epoch 110, Loss: 189.4731
# Validation Loss: 188.7518
# Epoch 120, Loss: 186.9424
# Validation Loss: 186.2736
# Epoch 130, Loss: 184.8355
# Validation Loss: 184.2051
# Epoch 140, Loss: 183.0142
# Validation Loss: 182.3943
# Epoch 150, Loss: 181.3418
# Validation Loss: 180.7442
# Epoch 160, Loss: 179.8631
# Validation Loss: 179.2915
# Epoch 170, Loss: 178.5538
# Validation Loss: 178.0105
# Epoch 180, Loss: 177.3773
# Validation Loss: 176.8543
# Epoch 190, Loss: 176.3111
# Validation Loss: 175.8129
# Epoch 200, Loss: 175.3773
# Validation Loss: 174.9102
# Epoch 210, Loss: 174.6066
# Validation Loss: 174.1772
# Epoch 220, Loss: 174.0328
# Validation Loss: 173.6348
# Epoch 230, Loss: 173.5721
# Validation Loss: 173.1923
# Epoch 240, Loss: 173.1628
# Validation Loss: 172.7945
# Epoch 250, Loss: 172.7795
# Validation Loss: 172.4182
# Epoch 260, Loss: 172.4083
# Validation Loss: 172.0516
# Epoch 270, Loss: 172.0432
# Validation Loss: 171.6899
# Epoch 280, Loss: 171.6832
# Validation Loss: 171.3326
# Epoch 290, Loss: 171.3301
# Validation Loss: 170.9825
# Epoch 300, Loss: 170.9853
# Validation Loss: 170.6402
# Epoch 310, Loss: 170.6504
# Validation Loss: 170.3073
# Epoch 320, Loss: 170.3230
# Validation Loss: 169.9806
# Epoch 330, Loss: 169.9809
# Validation Loss: 169.6378
# Epoch 340, Loss: 169.6132
# Validation Loss: 169.2785
# Epoch 350, Loss: 169.2963
# Validation Loss: 168.9721
# Epoch 360, Loss: 168.9915
# Validation Loss: 168.6754
# Epoch 370, Loss: 168.7118
# Validation Loss: 168.4040
# Epoch 380, Loss: 168.4611
# Validation Loss: 168.1607
# Epoch 390, Loss: 168.2433
# Validation Loss: 167.9514
# Epoch 400, Loss: 168.0554
# Validation Loss: 167.7711
# Epoch 410, Loss: 167.8924
# Validation Loss: 167.6129
# Epoch 420, Loss: 167.7487
# Validation Loss: 167.4727
# Epoch 430, Loss: 167.6253
# Validation Loss: 167.3513
# Epoch 440, Loss: 167.5228
# Validation Loss: 167.2499
# Epoch 450, Loss: 167.4396
# Validation Loss: 167.1669
# Epoch 460, Loss: 167.3713
# Validation Loss: 167.0972
# Epoch 470, Loss: 167.3142
# Validation Loss: 167.0380
# Epoch 480, Loss: 167.2655
# Validation Loss: 166.9874
# Epoch 490, Loss: 167.2240
# Validation Loss: 166.9435

# %%
def predict_distance(node1, node2, model):
    try:
        # Lấy tọa độ
        lat1 = G.nodes[node1]['y']
        lon1 = G.nodes[node1]['x']
        lat2 = G.nodes[node2]['y']
        lon2 = G.nodes[node2]['x']
        
        # Tính Euclidean distance
        euc_dist = euclidean(lat1, lon1, lat2, lon2)
        
        # Tạo tensor input đúng kích thước
        features = torch.tensor([lat1, lon1, lat2, lon2, euc_dist], 
                              dtype=torch.float32).reshape(1, -1)
        
        # Dự đoán
        model.eval()
        with torch.no_grad():
            output = model(features)
            
        return output[0][0].item()  # Lấy giá trị khoảng cách
        
    except Exception as e:
        print(f"Lỗi khi dự đoán: {str(e)}")
        return None

# %%
# Test model
nodes = list(G.nodes)[:10]
for i, node1 in enumerate(nodes):
    for j, node2 in enumerate(nodes):
        if i != j:
            pred_dist = predict_distance(node1, node2, model)
            if pred_dist is not None:
                print("\n")
                print(f"Khoảng cách từ {node1} đến {node2}: {pred_dist:.2f} mét")
                print(f"Khoảng cách thực tế theo đường chim bay: {euclidean(G.nodes[node1]['y'], G.nodes[node1]['x'], G.nodes[node2]['y'], G.nodes[node2]['x']):.2f} mét")
                print(f"Khoảng cách thực tế từ shortest_path: {nx.shortest_path_length(G, source=node1, target=node2, weight='length'):.2f} mét")
# Out:
# Khoảng cách từ 5704540253 đến 5704540254: 702.77 mét
# Khoảng cách thực tế theo đường chim bay: 255.33 mét
# Khoảng cách thực tế từ shortest_path: 570.00 mét
#
#
# Khoảng cách từ 5704540253 đến 5704540256: 835.71 mét
# Khoảng cách thực tế theo đường chim bay: 329.87 mét
# Khoảng cách thực tế từ shortest_path: 482.14 mét
#
#
# Khoảng cách từ 5704540253 đến 6441123934: 1411.68 mét
# Khoảng cách thực tế theo đường chim bay: 979.22 mét
# Khoảng cách thực tế từ shortest_path: 1329.11 mét
#
#
# Khoảng cách từ 5704540253 đến 6688497762: 2466.99 mét
# Khoảng cách thực tế theo đường chim bay: 1967.19 mét
# Khoảng cách thực tế từ shortest_path: 2183.92 mét
#
#
# Khoảng cách từ 5704540253 đến 10826334340: 451.56 mét
# Khoảng cách thực tế theo đường chim bay: 161.14 mét
# Khoảng cách thực tế từ shortest_path: 816.84 mét
#
#
# Khoảng cách từ 5704540253 đến 12223897784: 302.67 mét
# Khoảng cách thực tế theo đường chim bay: 114.32 mét
# Khoảng cách thực tế từ shortest_path: 146.05 mét
#
#
# Khoảng cách từ 5704540253 đến 5706891493: 1169.20 mét
# Khoảng cách thực tế theo đường chim bay: 716.58 mét
# Khoảng cách thực tế từ shortest_path: 1147.02 mét
#
#
# Khoảng cách từ 5704540253 đến 5706891494: 1189.02 mét
# Khoảng cách thực tế theo đường chim bay: 740.56 mét
# Khoảng cách thực tế từ shortest_path: 1089.57 mét
#
#
# Khoảng cách từ 5704540253 đến 5706891495: 1416.53 mét
# Khoảng cách thực tế theo đường chim bay: 984.25 mét
# Khoảng cách thực tế từ shortest_path: 1098.41 mét
#
#
# Khoảng cách từ 5704540254 đến 5704540253: 702.77 mét
# Khoảng cách thực tế theo đường chim bay: 255.33 mét
# Khoảng cách thực tế từ shortest_path: 570.00 mét
#
#
# Khoảng cách từ 5704540254 đến 5704540256: 233.86 mét
# Khoảng cách thực tế theo đường chim bay: 87.97 mét
# Khoảng cách thực tế từ shortest_path: 87.87 mét
#
#
# Khoảng cách từ 5704540254 đến 6441123934: 1294.98 mét
# Khoảng cách thực tế theo đường chim bay: 855.24 mét
# Khoảng cách thực tế từ shortest_path: 1350.38 mét
#
#
# Khoảng cách từ 5704540254 đến 6688497762: 2376.45 mét
# Khoảng cách thực tế theo đường chim bay: 1883.30 mét
# Khoảng cách thực tế từ shortest_path: 2329.50 mét
#
#
# Khoảng cách từ 5704540254 đến 10826334340: 441.97 mét
# Khoảng cách thực tế theo đường chim bay: 158.13 mét
# Khoảng cách thực tế từ shortest_path: 422.57 mét
#
#
# Khoảng cách từ 5704540254 đến 12223897784: 388.34 mét
# Khoảng cách thực tế theo đường chim bay: 141.30 mét
# Khoảng cách thực tế từ shortest_path: 423.96 mét
#
#
# Khoảng cách từ 5704540254 đến 5706891493: 1171.13 mét
# Khoảng cách thực tế theo đường chim bay: 719.30 mét
# Khoảng cách thực tế từ shortest_path: 1292.60 mét
#
#
# Khoảng cách từ 5704540254 đến 5706891494: 1206.74 mét
# Khoảng cách thực tế theo đường chim bay: 759.74 mét
# Khoảng cách thực tế từ shortest_path: 1235.15 mét
#
#
# Khoảng cách từ 5704540254 đến 5706891495: 1333.79 mét
# Khoảng cách thực tế theo đường chim bay: 897.22 mét
# Khoảng cách thực tế từ shortest_path: 1243.99 mét
#
#
# Khoảng cách từ 5704540256 đến 5704540253: 835.71 mét
# Khoảng cách thực tế theo đường chim bay: 329.87 mét
# Khoảng cách thực tế từ shortest_path: 482.14 mét
#
#
# Khoảng cách từ 5704540256 đến 5704540254: 233.86 mét
# Khoảng cách thực tế theo đường chim bay: 87.97 mét
# Khoảng cách thực tế từ shortest_path: 87.87 mét
#
#
# Khoảng cách từ 5704540256 đến 6441123934: 1226.68 mét
# Khoảng cách thực tế theo đường chim bay: 781.33 mét
# Khoảng cách thực tế từ shortest_path: 1262.51 mét
#
#
# Khoảng cách từ 5704540256 đến 6688497762: 2301.95 mét
# Khoảng cách thực tế theo đường chim bay: 1814.27 mét
# Khoảng cách thực tế từ shortest_path: 2241.63 mét
#
#
# Khoảng cách từ 5704540256 đến 10826334340: 679.69 mét
# Khoảng cách thực tế theo đường chim bay: 246.10 mét
# Khoảng cách thực tế từ shortest_path: 334.70 mét
#
#
# Khoảng cách từ 5704540256 đến 12223897784: 613.12 mét
# Khoảng cách thực tế theo đường chim bay: 219.51 mét
# Khoảng cách thực tế từ shortest_path: 336.09 mét
#
#
# Khoảng cách từ 5704540256 đến 5706891493: 1146.85 mét
# Khoảng cách thực tế theo đường chim bay: 685.11 mét
# Khoảng cách thực tế từ shortest_path: 1204.74 mét
#
#
# Khoảng cách từ 5704540256 đến 5706891494: 1179.17 mét
# Khoảng cách thực tế theo đường chim bay: 729.91 mét
# Khoảng cách thực tế từ shortest_path: 1147.29 mét
#
#
# Khoảng cách từ 5704540256 đến 5706891495: 1273.88 mét
# Khoảng cách thực tế theo đường chim bay: 832.40 mét
# Khoảng cách thực tế từ shortest_path: 1156.12 mét
#
#
# Khoảng cách từ 6441123934 đến 5704540253: 1411.68 mét
# Khoảng cách thực tế theo đường chim bay: 979.22 mét
# Khoảng cách thực tế từ shortest_path: 1425.70 mét
#
#
# Khoảng cách từ 6441123934 đến 5704540254: 1294.98 mét
# Khoảng cách thực tế theo đường chim bay: 855.24 mét
# Khoảng cách thực tế từ shortest_path: 1350.38 mét
#
#
# Khoảng cách từ 6441123934 đến 5704540256: 1226.67 mét
# Khoảng cách thực tế theo đường chim bay: 781.33 mét
# Khoảng cách thực tế từ shortest_path: 1262.51 mét
#
#
# Khoảng cách từ 6441123934 đến 6688497762: 1468.14 mét
# Khoảng cách thực tế theo đường chim bay: 1037.36 mét
# Khoảng cách thực tế từ shortest_path: 1397.43 mét
#
#
# Khoảng cách từ 6441123934 đến 10826334340: 1426.26 mét
# Khoảng cách thực tế theo đường chim bay: 994.26 mét
# Khoảng cách thực tế từ shortest_path: 1597.21 mét
#
#
# Khoảng cách từ 6441123934 đến 12223897784: 1357.51 mét
# Khoảng cách thực tế theo đường chim bay: 922.35 mét
# Khoảng cách thực tế từ shortest_path: 1437.55 mét
#
#
# Khoảng cách từ 6441123934 đến 5706891493: 988.03 mét
# Khoảng cách thực tế theo đường chim bay: 461.44 mét
# Khoảng cách thực tế từ shortest_path: 851.28 mét
#
#
# Khoảng cách từ 6441123934 đến 5706891494: 1018.90 mét
# Khoảng cách thực tế theo đường chim bay: 504.93 mét
# Khoảng cách thực tế từ shortest_path: 793.83 mét
#
#
# Khoảng cách từ 6441123934 đến 5706891495: 414.16 mét
# Khoảng cách thực tế theo đường chim bay: 149.40 mét
# Khoảng cách thực tế từ shortest_path: 491.29 mét
#
#
# Khoảng cách từ 6688497762 đến 5704540253: 2466.98 mét
# Khoảng cách thực tế theo đường chim bay: 1967.19 mét
# Khoảng cách thực tế từ shortest_path: 2240.59 mét
#
#
# Khoảng cách từ 6688497762 đến 5704540254: 2376.43 mét
# Khoảng cách thực tế theo đường chim bay: 1883.30 mét
# Khoảng cách thực tế từ shortest_path: 2329.02 mét
#
#
# Khoảng cách từ 6688497762 đến 5704540256: 2301.93 mét
# Khoảng cách thực tế theo đường chim bay: 1814.27 mét
# Khoảng cách thực tế từ shortest_path: 2241.15 mét
#
#
# Khoảng cách từ 6688497762 đến 6441123934: 1468.14 mét
# Khoảng cách thực tế theo đường chim bay: 1037.36 mét
# Khoảng cách thực tế từ shortest_path: 1389.61 mét
#
#
# Khoảng cách từ 6688497762 đến 10826334340: 2514.91 mét
# Khoảng cách thực tế theo đường chim bay: 2011.61 mét
# Khoảng cách thực tế từ shortest_path: 2575.85 mét
#
#
# Khoảng cách từ 6688497762 đến 12223897784: 2428.63 mét
# Khoảng cách thực tế theo đường chim bay: 1931.67 mét
# Khoảng cách thực tế từ shortest_path: 2252.44 mét
#
#
# Khoảng cách từ 6688497762 đến 5706891493: 1724.89 mét
# Khoảng cách thực tế theo đường chim bay: 1279.59 mét
# Khoảng cách thực tế từ shortest_path: 1666.17 mét
#
#
# Khoảng cách từ 6688497762 đến 5706891494: 1723.91 mét
# Khoảng cách thực tế theo đường chim bay: 1278.68 mét
# Khoảng cách thực tế từ shortest_path: 1608.72 mét
#
#
# Khoảng cách từ 6688497762 đến 5706891495: 1420.75 mét
# Khoảng cách thực tế theo đường chim bay: 988.63 mét
# Khoảng cách thực tế từ shortest_path: 1591.64 mét
#
#
# Khoảng cách từ 10826334340 đến 5704540253: 451.56 mét
# Khoảng cách thực tế theo đường chim bay: 161.14 mét
# Khoảng cách thực tế từ shortest_path: 410.75 mét
#
#
# Khoảng cách từ 10826334340 đến 5704540254: 441.97 mét
# Khoảng cách thực tế theo đường chim bay: 158.13 mét
# Khoảng cách thực tế từ shortest_path: 726.49 mét
#
#
# Khoảng cách từ 10826334340 đến 5704540256: 679.69 mét
# Khoảng cách thực tế theo đường chim bay: 246.10 mét
# Khoảng cách thực tế từ shortest_path: 638.62 mét
#
#
# Khoảng cách từ 10826334340 đến 6441123934: 1426.27 mét
# Khoảng cách thực tế theo đường chim bay: 994.26 mét
# Khoảng cách thực tế từ shortest_path: 1662.24 mét
#
#
# Khoảng cách từ 10826334340 đến 6688497762: 2514.93 mét
# Khoảng cách thực tế theo đường chim bay: 2011.61 mét
# Khoảng cách thực tế từ shortest_path: 2517.05 mét
#
#
# Khoảng cách từ 10826334340 đến 12223897784: 241.89 mét
# Khoảng cách thực tế theo đường chim bay: 91.08 mét
# Khoảng cách thực tế từ shortest_path: 302.54 mét
#
#
# Khoảng cách từ 10826334340 đến 5706891493: 1246.12 mét
# Khoảng cách thực tế theo đường chim bay: 802.34 mét
# Khoảng cách thực tế từ shortest_path: 1480.15 mét
#
#
# Khoảng cách từ 10826334340 đến 5706891494: 1276.28 mét
# Khoảng cách thực tế theo đường chim bay: 834.98 mét
# Khoảng cách thực tế từ shortest_path: 1422.70 mét
#
#
# Khoảng cách từ 10826334340 đến 5706891495: 1454.21 mét
# Khoảng cách thực tế theo đường chim bay: 1022.98 mét
# Khoảng cách thực tế từ shortest_path: 1431.54 mét
#
#
# Khoảng cách từ 12223897784 đến 5704540253: 302.67 mét
# Khoảng cách thực tế theo đường chim bay: 114.32 mét
# Khoảng cách thực tế từ shortest_path: 146.05 mét
#
#
# Khoảng cách từ 12223897784 đến 5704540254: 388.34 mét
# Khoảng cách thực tế theo đường chim bay: 141.30 mét
# Khoảng cách thực tế từ shortest_path: 423.96 mét
#
#
# Khoảng cách từ 12223897784 đến 5704540256: 613.12 mét
# Khoảng cách thực tế theo đường chim bay: 219.51 mét
# Khoảng cách thực tế từ shortest_path: 336.09 mét
#
#
# Khoảng cách từ 12223897784 đến 6441123934: 1357.51 mét
# Khoảng cách thực tế theo đường chim bay: 922.35 mét
# Khoảng cách thực tế từ shortest_path: 1397.55 mét
#
#
# Khoảng cách từ 12223897784 đến 6688497762: 2428.65 mét
# Khoảng cách thực tế theo đường chim bay: 1931.67 mét
# Khoảng cách thực tế từ shortest_path: 2252.35 mét
#
#
# Khoảng cách từ 12223897784 đến 10826334340: 241.89 mét
# Khoảng cách thực tế theo đường chim bay: 91.08 mét
# Khoảng cách thực tế từ shortest_path: 670.79 mét
#
#
# Khoảng cách từ 12223897784 đến 5706891493: 1166.33 mét
# Khoảng cách thực tế theo đường chim bay: 712.54 mét
# Khoảng cách thực tế từ shortest_path: 1215.46 mét
#
#
# Khoảng cách từ 12223897784 đến 5706891494: 1192.58 mét
# Khoảng cách thực tế theo đường chim bay: 744.41 mét
# Khoảng cách thực tế từ shortest_path: 1158.01 mét
#
#
# Khoảng cách từ 12223897784 đến 5706891495: 1377.61 mét
# Khoảng cách thực tế theo đường chim bay: 943.44 mét
# Khoảng cách thực tế từ shortest_path: 1166.84 mét
#
#
# Khoảng cách từ 5706891493 đến 5704540253: 1169.20 mét
# Khoảng cách thực tế theo đường chim bay: 716.58 mét
# Khoảng cách thực tế từ shortest_path: 1189.12 mét
#
#
# Khoảng cách từ 5706891493 đến 5704540254: 1171.13 mét
# Khoảng cách thực tế theo đường chim bay: 719.30 mét
# Khoảng cách thực tế từ shortest_path: 1277.55 mét
#
#
# Khoảng cách từ 5706891493 đến 5704540256: 1146.85 mét
# Khoảng cách thực tế theo đường chim bay: 685.11 mét
# Khoảng cách thực tế từ shortest_path: 1189.68 mét
#
#
# Khoảng cách từ 5706891493 đến 6441123934: 988.03 mét
# Khoảng cách thực tế theo đường chim bay: 461.44 mét
# Khoảng cách thực tế từ shortest_path: 863.02 mét
#
#
# Khoảng cách từ 5706891493 đến 6688497762: 1724.90 mét
# Khoảng cách thực tế theo đường chim bay: 1279.59 mét
# Khoảng cách thực tế từ shortest_path: 1717.82 mét
#
#
# Khoảng cách từ 5706891493 đến 10826334340: 1246.11 mét
# Khoảng cách thực tế theo đường chim bay: 802.34 mét
# Khoảng cách thực tế từ shortest_path: 1524.38 mét
#
#
# Khoảng cách từ 5706891493 đến 12223897784: 1166.33 mét
# Khoảng cách thực tế theo đường chim bay: 712.54 mét
# Khoảng cách thực tế từ shortest_path: 1200.97 mét
#
#
# Khoảng cách từ 5706891493 đến 5706891494: 158.24 mét
# Khoảng cách thực tế theo đường chim bay: 57.51 mét
# Khoảng cách thực tế từ shortest_path: 57.45 mét
#
#
# Khoảng cách từ 5706891493 đến 5706891495: 898.02 mét
# Khoảng cách thực tế theo đường chim bay: 369.60 mét
# Khoảng cách thực tế từ shortest_path: 632.31 mét
#
#
# Khoảng cách từ 5706891494 đến 5704540253: 1189.02 mét
# Khoảng cách thực tế theo đường chim bay: 740.56 mét
# Khoảng cách thực tế từ shortest_path: 1131.67 mét
#
#
# Khoảng cách từ 5706891494 đến 5704540254: 1206.73 mét
# Khoảng cách thực tế theo đường chim bay: 759.74 mét
# Khoảng cách thực tế từ shortest_path: 1220.10 mét
#
#
# Khoảng cách từ 5706891494 đến 5704540256: 1179.17 mét
# Khoảng cách thực tế theo đường chim bay: 729.91 mét
# Khoảng cách thực tế từ shortest_path: 1132.24 mét
#
#
# Khoảng cách từ 5706891494 đến 6441123934: 1018.91 mét
# Khoảng cách thực tế theo đường chim bay: 504.93 mét
# Khoảng cách thực tế từ shortest_path: 805.57 mét
#
#
# Khoảng cách từ 5706891494 đến 6688497762: 1723.92 mét
# Khoảng cách thực tế theo đường chim bay: 1278.68 mét
# Khoảng cách thực tế từ shortest_path: 1660.37 mét
#
#
# Khoảng cách từ 5706891494 đến 10826334340: 1276.28 mét
# Khoảng cách thực tế theo đường chim bay: 834.98 mét
# Khoảng cách thực tế từ shortest_path: 1466.93 mét
#
#
# Khoảng cách từ 5706891494 đến 12223897784: 1192.57 mét
# Khoảng cách thực tế theo đường chim bay: 744.41 mét
# Khoảng cách thực tế từ shortest_path: 1143.52 mét
#
#
# Khoảng cách từ 5706891494 đến 5706891493: 158.24 mét
# Khoảng cách thực tế theo đường chim bay: 57.51 mét
# Khoảng cách thực tế từ shortest_path: 57.45 mét
#
#
# Khoảng cách từ 5706891494 đến 5706891495: 946.19 mét
# Khoảng cách thực tế theo đường chim bay: 401.81 mét
# Khoảng cách thực tế từ shortest_path: 574.86 mét
#
#
# Khoảng cách từ 5706891495 đến 5704540253: 1416.53 mét
# Khoảng cách thực tế theo đường chim bay: 984.25 mét
# Khoảng cách thực tế từ shortest_path: 1276.98 mét
#
#
# Khoảng cách từ 5706891495 đến 5704540254: 1333.79 mét
# Khoảng cách thực tế theo đường chim bay: 897.22 mét
# Khoảng cách thực tế từ shortest_path: 1365.41 mét
#
#
# Khoảng cách từ 5706891495 đến 5704540256: 1273.87 mét
# Khoảng cách thực tế theo đường chim bay: 832.40 mét
# Khoảng cách thực tế từ shortest_path: 1277.55 mét
#
#
# Khoảng cách từ 5706891495 đến 6441123934: 414.16 mét
# Khoảng cách thực tế theo đường chim bay: 149.40 mét
# Khoảng cách thực tế từ shortest_path: 393.91 mét
#
#
# Khoảng cách từ 5706891495 đến 6688497762: 1420.75 mét
# Khoảng cách thực tế theo đường chim bay: 988.63 mét
# Khoảng cách thực tế từ shortest_path: 1248.71 mét
#
#
# Khoảng cách từ 5706891495 đến 10826334340: 1454.21 mét
# Khoảng cách thực tế theo đường chim bay: 1022.98 mét
# Khoảng cách thực tế từ shortest_path: 1612.24 mét
#
#
# Khoảng cách từ 5706891495 đến 12223897784: 1377.61 mét
# Khoảng cách thực tế theo đường chim bay: 943.44 mét
# Khoảng cách thực tế từ shortest_path: 1288.83 mét
#
#
# Khoảng cách từ 5706891495 đến 5706891493: 898.01 mét
# Khoảng cách thực tế theo đường chim bay: 369.60 mét
# Khoảng cách thực tế từ shortest_path: 702.56 mét
#
#
# Khoảng cách từ 5706891495 đến 5706891494: 946.19 mét
# Khoảng cách thực tế theo đường chim bay: 401.81 mét
# Khoảng cách thực tế từ shortest_path: 645.11 mét

# %%
import joblib
joblib.dump(model, 'ml_heuristic_model.pkl')
# Out:
# ['ml_heuristic_model.pkl']
